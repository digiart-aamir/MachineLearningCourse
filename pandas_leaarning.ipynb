# %% [markdown]
# ![img](ML.png)

# %%
import pandas as pd

# %% [markdown]
# # types of data in pandas

# %%
# 2 main data types
series = pd.Series(["fei","sss","www"])

# %%
series
# Out:
# 0    fei
# 1    sss
# 2    www
# dtype: object

# %%
value= pd.Series([1,2,3])

# %%
value
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
#dataframe 2d

# %%
car_data= pd.DataFrame({"Car make": series, "value":value})

# %%
car_data
# Out:
#   Car make  value
# 0      fei      1
# 1      sss      2
# 2      www      3

# %% [markdown]
# # import and export data

# %%
data = pd.read_csv("car-sales.csv")

# %%
data
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White     34564      4    $5.00
# 1   Honda    Red      3456      4    $7.00
# 2     BMW   Blue     34567      4   $56.00
# 3     BMW  Black     34567      3    $4.00
# 4     BMW  Green      9876      5    $7.00
# 5  Nissan   Blue     87654      4   $22.00
# 6  Toyota   Blue       345      4    $7.00
# 7   Honda  White     65466      4    $8.00
# 8     BMW  White      2344      4   $12.00
# 9  Nissan  Black      8765      4    $9.00

# %%
data.to_csv("exported_sales.csv", index=0)

# %% [markdown]
# # Describe data

# %%
data
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White     34564      4    $5.00
# 1   Honda    Red      3456      4    $7.00
# 2     BMW   Blue     34567      4   $56.00
# 3     BMW  Black     34567      3    $4.00
# 4     BMW  Green      9876      5    $7.00
# 5  Nissan   Blue     87654      4   $22.00
# 6  Toyota   Blue       345      4    $7.00
# 7   Honda  White     65466      4    $8.00
# 8     BMW  White      2344      4   $12.00
# 9  Nissan  Black      8765      4    $9.00

# %%
#attribute
data.dtypes
# Out:
# Make        object
# Colour      object
# Odometer     int64
# Doors        int64
# Price       object
# dtype: object

# %%
data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer', 'Doors', 'Price'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data.describe()
# Out:
#            Odometer      Doors
# count     10.000000  10.000000
# mean   28160.400000   4.000000
# std    29468.028932   0.471405
# min      345.000000   3.000000
# 25%     4783.250000   4.000000
# 50%    22220.000000   4.000000
# 75%    34567.000000   4.000000
# max    87654.000000   5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      10 non-null     object
#  1   Colour    10 non-null     object
#  2   Odometer  10 non-null     int64
#  3   Doors     10 non-null     int64
#  4   Price     10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
data.sum()
# Out:
# Make           ToyotaHondaBMWBMWBMWNissanToyotaHondaBMWNissan
# Colour          WhiteRedBlueBlackGreenBlueBlueWhiteWhiteBlack
# Odometer                                               281604
# Doors                                                      40
# Price        $5.00  $7.00  $56.00  $4.00  $7.00  $22.00  $...
# dtype: object

# %%
data.mean()
# Out:
# C:\Users\sunrise\AppData\Local\Temp\ipykernel_17504\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Odometer    28160.4
# Doors           4.0
# dtype: float64

# %%
len(data)
# Out:
# 10

# %%
data.head()
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White     34564      4    $5.00
# 1   Honda    Red      3456      4    $7.00
# 2     BMW   Blue     34567      4   $56.00
# 3     BMW  Black     34567      3    $4.00
# 4     BMW  Green      9876      5    $7.00

# %% [markdown]
# # viewing and selecting data

# %%
data.head(8)
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White     34564      4    $5.00
# 1   Honda    Red      3456      4    $7.00
# 2     BMW   Blue     34567      4   $56.00
# 3     BMW  Black     34567      3    $4.00
# 4     BMW  Green      9876      5    $7.00
# 5  Nissan   Blue     87654      4   $22.00
# 6  Toyota   Blue       345      4    $7.00
# 7   Honda  White     65466      4    $8.00

# %%
data.tail()
# Out:
#      Make Colour  Odometer  Doors     Price
# 5  Nissan   Blue     87654      4   $22.00
# 6  Toyota   Blue       345      4    $7.00
# 7   Honda  White     65466      4    $8.00
# 8     BMW  White      2344      4   $12.00
# 9  Nissan  Black      8765      4    $9.00

# %%
#.loc and .iloc
series.loc[2]
# Out:
# 'www'

# %%
data.loc[3]
# Out:
# Make            BMW
# Colour        Black
# Odometer      34567
# Doors             3
# Price        $4.00
# Name: 3, dtype: object

# %%
data.loc[4:]
# Out:
#      Make Colour  Odometer  Doors     Price
# 4     BMW  Green      9876      5    $7.00
# 5  Nissan   Blue     87654      4   $22.00
# 6  Toyota   Blue       345      4    $7.00
# 7   Honda  White     65466      4    $8.00
# 8     BMW  White      2344      4   $12.00
# 9  Nissan  Black      8765      4    $9.00

# %%
data.iloc[3:6]
# Out:
#      Make Colour  Odometer  Doors     Price
# 3     BMW  Black     34567      3    $4.00
# 4     BMW  Green      9876      5    $7.00
# 5  Nissan   Blue     87654      4   $22.00

# %%
data[data["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White     34564      4   $5.00
# 6  Toyota   Blue       345      4   $7.00

# %%
pd.crosstab(data["Make"], data["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     1  2  1
# Honda   0  2  0
# Nissan  0  2  0
# Toyota  0  2  0

# %%
data.groupby (["Make"]) .mean()
# Out:
# C:\Users\sunrise\AppData\Local\Temp\ipykernel_17504\3966465095.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby (["Make"]) .mean()
#         Odometer  Doors
# Make
# BMW      20338.5    4.0
# Honda    34461.0    4.0
# Nissan   48209.5    4.0
# Toyota   17454.5    4.0

# %%
data["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 data["Price"].plot()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
# ...

# %%
data["Doors"].plot()
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# Make        object
# Colour      object
# Odometer     int64
# Doors        int64
# Price       object
# dtype: object

# %%
data
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White     34564      4    $5.00
# 1   Honda    Red      3456      4    $7.00
# 2     BMW   Blue     34567      4   $56.00
# 3     BMW  Black     34567      3    $4.00
# 4     BMW  Green      9876      5    $7.00
# 5  Nissan   Blue     87654      4   $22.00
# 6  Toyota   Blue       345      4    $7.00
# 7   Honda  White     65466      4    $8.00
# 8     BMW  White      2344      4   $12.00
# 9  Nissan  Black      8765      4    $9.00

# %%
data["Price"]= data["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# C:\Users\sunrise\AppData\Local\Temp\ipykernel_17504\1175181303.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Price"]= data["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
data
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White     34564      4    500
# 1   Honda    Red      3456      4    700
# 2     BMW   Blue     34567      4   5600
# 3     BMW  Black     34567      3    400
# 4     BMW  Green      9876      5    700
# 5  Nissan   Blue     87654      4   2200
# 6  Toyota   Blue       345      4    700
# 7   Honda  White     65466      4    800
# 8     BMW  White      2344      4   1200
# 9  Nissan  Black      8765      4    900

# %%
data["Price"]= data["Price"]*100

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  Toyota  White     34564      4   50000
# 1   Honda    Red      3456      4   70000
# 2     BMW   Blue     34567      4  560000
# 3     BMW  Black     34567      3   40000
# 4     BMW  Green      9876      5   70000
# 5  Nissan   Blue     87654      4  220000
# 6  Toyota   Blue       345      4   70000
# 7   Honda  White     65466      4   80000
# 8     BMW  White      2344      4  120000
# 9  Nissan  Black      8765      4   90000

# %%
data["Price"].plot()
# Out:
# <Axes: >

# %%
plot= data["Price"].hist()

# %%
plot.savefig('plot.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 plot.savefig('plot.png')
#
# AttributeError: 'Axes' object has no attribute 'savefig'

# %% [markdown]
# # Manipulation of data

# %%
data["Make"]=data["Make"].str.lower()

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  toyota  White     34564      4   50000
# 1   honda    Red      3456      4   70000
# 2     bmw   Blue     34567      4  560000
# 3     bmw  Black     34567      3   40000
# 4     bmw  Green      9876      5   70000
# 5  nissan   Blue     87654      4  220000
# 6  toyota   Blue       345      4   70000
# 7   honda  White     65466      4   80000
# 8     bmw  White      2344      4  120000
# 9  nissan  Black      8765      4   90000

# %%
data["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2       BMW
# 3       BMW
# 4       BMW
# 5    NISSAN
# 6    TOYOTA
# 7     HONDA
# 8       BMW
# 9    NISSAN
# Name: Make, dtype: object

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  toyota  White     34564      4   50000
# 1   honda    Red      3456      4   70000
# 2     bmw   Blue     34567      4  560000
# 3     bmw  Black     34567      3   40000
# 4     bmw  Green      9876      5   70000
# 5  nissan   Blue     87654      4  220000
# 6  toyota   Blue       345      4   70000
# 7   honda  White     65466      4   80000
# 8     bmw  White      2344      4  120000
# 9  nissan  Black      8765      4   90000

# %%
data["Make"]=data["Make"].str.capitalize()

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  Toyota  White     34564      4   50000
# 1   Honda    Red      3456      4   70000
# 2     Bmw   Blue     34567      4  560000
# 3     Bmw  Black     34567      3   40000
# 4     Bmw  Green      9876      5   70000
# 5  Nissan   Blue     87654      4  220000
# 6  Toyota   Blue       345      4   70000
# 7   Honda  White     65466      4   80000
# 8     Bmw  White      2344      4  120000
# 9  Nissan  Black      8765      4   90000

# %%
data.to_csv("car_sale_missing")

# %%
data1= pd.read_csv("car_sale_missing")

# %%
data1
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price
# 0           0  Toyota  White     34564      4   50000
# 1           1   Honda    Red      3456      4   70000
# 2           2     Bmw   Blue     34567      4  560000
# 3           3     Bmw  Black     34567      3   40000
# 4           4     Bmw  Green      9876      5   70000
# 5           5  Nissan   Blue     87654      4  220000
# 6           6  Toyota   Blue       345      4   70000
# 7           7   Honda  White     65466      4   80000
# 8           8     Bmw  White      2344      4  120000
# 9           9  Nissan  Black      8765      4   90000

# %%
data1["Odometer"]= data1["Odometer"].fillna(data1["Odometer"].mean())

# %%
data1
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price
# 0           0  Toyota  White     34564      4   50000
# 1           1   Honda    Red      3456      4   70000
# 2           2     Bmw   Blue     34567      4  560000
# 3           3     Bmw  Black     34567      3   40000
# 4           4     Bmw  Green      9876      5   70000
# 5           5  Nissan   Blue     87654      4  220000
# 6           6  Toyota   Blue       345      4   70000
# 7           7   Honda  White     65466      4   80000
# 8           8     Bmw  White      2344      4  120000
# 9           9  Nissan  Black      8765      4   90000

# %%
  data1.dropna()
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price
# 0           0  Toyota  White     34564      4   50000
# 1           1   Honda    Red      3456      4   70000
# 2           2     Bmw   Blue     34567      4  560000
# 3           3     Bmw  Black     34567      3   40000
# 4           4     Bmw  Green      9876      5   70000
# 5           5  Nissan   Blue     87654      4  220000
# 6           6  Toyota   Blue       345      4   70000
# 7           7   Honda  White     65466      4   80000
# 8           8     Bmw  White      2344      4  120000
# 9           9  Nissan  Black      8765      4   90000

# %%
data2= data1.dropna()

# %%
data2
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price
# 0           0  Toyota  White     34564      4   50000
# 1           1   Honda    Red      3456      4   70000
# 2           2     Bmw   Blue     34567      4  560000
# 3           3     Bmw  Black     34567      3   40000
# 4           4     Bmw  Green      9876      5   70000
# 5           5  Nissan   Blue     87654      4  220000
# 6           6  Toyota   Blue       345      4   70000
# 7           7   Honda  White     65466      4   80000
# 8           8     Bmw  White      2344      4  120000
# 9           9  Nissan  Black      8765      4   90000

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  Toyota  White     34564      4   50000
# 1   Honda    Red      3456      4   70000
# 2     Bmw   Blue     34567      4  560000
# 3     Bmw  Black     34567      3   40000
# 4     Bmw  Green      9876      5   70000
# 5  Nissan   Blue     87654      4  220000
# 6  Toyota   Blue       345      4   70000
# 7   Honda  White     65466      4   80000
# 8     Bmw  White      2344      4  120000
# 9  Nissan  Black      8765      4   90000

# %%
data1
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price
# 0           0  Toyota  White     34564      4   50000
# 1           1   Honda    Red      3456      4   70000
# 2           2     Bmw   Blue     34567      4  560000
# 3           3     Bmw  Black     34567      3   40000
# 4           4     Bmw  Green      9876      5   70000
# 5           5  Nissan   Blue     87654      4  220000
# 6           6  Toyota   Blue       345      4   70000
# 7           7   Honda  White     65466      4   80000
# 8           8     Bmw  White      2344      4  120000
# 9           9  Nissan  Black      8765      4   90000

# %%
seats= pd.Series([5,5,4,3])
seats
# Out:
# 0    5
# 1    5
# 2    4
# 3    3
# dtype: int64

# %%
 data2["Seats"]= seats

# %%
data2
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price  Seats
# 0           0  Toyota  White     34564      4   50000    5.0
# 1           1   Honda    Red      3456      4   70000    5.0
# 2           2     Bmw   Blue     34567      4  560000    4.0
# 3           3     Bmw  Black     34567      3   40000    3.0
# 4           4     Bmw  Green      9876      5   70000    NaN
# 5           5  Nissan   Blue     87654      4  220000    NaN
# 6           6  Toyota   Blue       345      4   70000    NaN
# 7           7   Honda  White     65466      4   80000    NaN
# 8           8     Bmw  White      2344      4  120000    NaN
# 9           9  Nissan  Black      8765      4   90000    NaN

# %%
data2
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors   Price  Seats
# 0           0  Toyota  White     34564      4   50000    5.0
# 1           1   Honda    Red      3456      4   70000    5.0
# 2           2     Bmw   Blue     34567      4  560000    4.0
# 3           3     Bmw  Black     34567      3   40000    3.0
# 4           4     Bmw  Green      9876      5   70000    NaN
# 5           5  Nissan   Blue     87654      4  220000    NaN
# 6           6  Toyota   Blue       345      4   70000    NaN
# 7           7   Honda  White     65466      4   80000    NaN
# 8           8     Bmw  White      2344      4  120000    NaN
# 9           9  Nissan  Black      8765      4   90000    NaN

# %%
fuel= [7,6,7,9]

# %%
fuel
# Out:
# [7.4, 6.4, 7.6, 9.0]

# %%
data2['fuel'] = fuel
print(data2)
# Out:
#    Unnamed: 0    Make Colour      Odometer  Doors   Price  Seats  fuel
# 0           2     Bmw   Blue  27448.555556    4.0  5600.0      5   7.4
# 1           3     Bmw  Black  34567.000000    3.0   400.0      5   6.4
# 2           5  Nissan   Blue  87654.000000    4.0  2200.0      4   7.6
# 3           8     Bmw  White   2344.000000    4.0  1200.0      3   9.0
# C:\Users\sunrise\AppData\Local\Temp\ipykernel_17504\2103129042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['fuel'] = fuel

# %%
data1
# Out:
#    Unnamed: 0    Make Colour      Odometer  Doors   Price
# 0           0  Toyota    NaN  34564.000000    4.0   500.0
# 1           1   Honda    NaN   3456.000000    4.0   700.0
# 2           2     Bmw   Blue  27448.555556    4.0  5600.0
# 3           3     Bmw  Black  34567.000000    3.0   400.0
# 4           4     Bmw  Green   9876.000000    NaN     NaN
# 5           5  Nissan   Blue  87654.000000    4.0  2200.0
# 6           6     NaN   Blue    345.000000    NaN   700.0
# 7           7   Honda    NaN  65466.000000    NaN   800.0
# 8           8     Bmw  White   2344.000000    4.0  1200.0
# 9           9  Nissan  Black   8765.000000    4.0     NaN

# %%
fuel=[3,5,5,4,5,6,5,4,6,3]

# %%
data["fuel"]
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  Toyota  White     34564      4   50000
# 1   Honda    Red      3456      4   70000
# 2     Bmw   Blue     34567      4  560000
# 3     Bmw  Black     34567      3   40000
# 4     Bmw  Green      9876      5   70000
# 5  Nissan   Blue     87654      4  220000
# 6  Toyota   Blue       345      4   70000
# 7   Honda  White     65466      4   80000
# 8     Bmw  White      2344      4  120000
# 9  Nissan  Black      8765      4   90000

# %%
data["fuel"]=fuel

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price  fuel
# 0  Toyota  White     34564      4   50000     3
# 1   Honda    Red      3456      4   70000     5
# 2     Bmw   Blue     34567      4  560000     5
# 3     Bmw  Black     34567      3   40000     4
# 4     Bmw  Green      9876      5   70000     5
# 5  Nissan   Blue     87654      4  220000     6
# 6  Toyota   Blue       345      4   70000     5
# 7   Honda  White     65466      4   80000     4
# 8     Bmw  White      2344      4  120000     6
# 9  Nissan  Black      8765      4   90000     3

# %%
data["total_fuel"]= data["Odometer"]*data["fuel"]

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price  fuel  total_fuel
# 0  Toyota  White     34564      4   50000     3      103692
# 1   Honda    Red      3456      4   70000     5       17280
# 2     Bmw   Blue     34567      4  560000     5      172835
# 3     Bmw  Black     34567      3   40000     4      138268
# 4     Bmw  Green      9876      5   70000     5       49380
# 5  Nissan   Blue     87654      4  220000     6      525924
# 6  Toyota   Blue       345      4   70000     5        1725
# 7   Honda  White     65466      4   80000     4      261864
# 8     Bmw  White      2344      4  120000     6       14064
# 9  Nissan  Black      8765      4   90000     3       26295

# %%
 data['wheels']=4

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price  fuel  total_fuel  wheels
# 0  Toyota  White     34564      4   50000     3      103692       4
# 1   Honda    Red      3456      4   70000     5       17280       4
# 2     Bmw   Blue     34567      4  560000     5      172835       4
# 3     Bmw  Black     34567      3   40000     4      138268       4
# 4     Bmw  Green      9876      5   70000     5       49380       4
# 5  Nissan   Blue     87654      4  220000     6      525924       4
# 6  Toyota   Blue       345      4   70000     5        1725       4
# 7   Honda  White     65466      4   80000     4      261864       4
# 8     Bmw  White      2344      4  120000     6       14064       4
# 9  Nissan  Black      8765      4   90000     3       26295       4

# %%
data.dtypes
# Out:
# Make          object
# Colour        object
# Odometer       int64
# Doors          int64
# Price          int32
# fuel           int64
# total_fuel     int64
# wheels         int64
# dtype: object

# %%
data
# Out:
#      Make Colour  Odometer  Doors   Price  fuel  total_fuel  wheels
# 0  Toyota  White     34564      4   50000     3      103692       4
# 1   Honda    Red      3456      4   70000     5       17280       4
# 2     Bmw   Blue     34567      4  560000     5      172835       4
# 3     Bmw  Black     34567      3   40000     4      138268       4
# 4     Bmw  Green      9876      5   70000     5       49380       4
# 5  Nissan   Blue     87654      4  220000     6      525924       4
# 6  Toyota   Blue       345      4   70000     5        1725       4
# 7   Honda  White     65466      4   80000     4      261864       4
# 8     Bmw  White      2344      4  120000     6       14064       4
# 9  Nissan  Black      8765      4   90000     3       26295       4

# %%
data =data.drop("fuel", axis=1)

# %%
data.sample(frac=0.5)
# Out:
#      Make Colour  Odometer  Doors   Price  total_fuel
# 2     Bmw   Blue     34567      4  560000      172835
# 7   Honda  White     65466      4   80000      261864
# 9  Nissan  Black      8765      4   90000       26295
# 8     Bmw  White      2344      4  120000       14064
# 6  Toyota   Blue       345      4   70000        1725

# %%
data.sample(frac=1)
# Out:
#      Make Colour  Odometer  Doors   Price  total_fuel
# 6  Toyota   Blue       345      4   70000        1725
# 3     Bmw  Black     34567      3   40000      138268
# 1   Honda    Red      3456      4   70000       17280
# 4     Bmw  Green      9876      5   70000       49380
# 2     Bmw   Blue     34567      4  560000      172835
# 7   Honda  White     65466      4   80000      261864
# 9  Nissan  Black      8765      4   90000       26295
# 0  Toyota  White     34564      4   50000      103692
# 5  Nissan   Blue     87654      4  220000      525924
# 8     Bmw  White      2344      4  120000       14064

# %%
data_shuffle= data.sample(frac=1)

# %%
data_shuffle.reset_index()
# Out:
#    index    Make Colour  Odometer  Doors   Price  total_fuel
# 0      1   Honda    Red      3456      4   70000       17280
# 1      3     Bmw  Black     34567      3   40000      138268
# 2      2     Bmw   Blue     34567      4  560000      172835
# 3      5  Nissan   Blue     87654      4  220000      525924
# 4      9  Nissan  Black      8765      4   90000       26295
# 5      7   Honda  White     65466      4   80000      261864
# 6      0  Toyota  White     34564      4   50000      103692
# 7      8     Bmw  White      2344      4  120000       14064
# 8      6  Toyota   Blue       345      4   70000        1725
# 9      4     Bmw  Green      9876      5   70000       49380

# %%
# choose only 20% of data
data.sample(frac=0.2)
# Out:
#      Make Colour  Odometer  Doors   Price  total_fuel
# 5  Nissan   Blue     87654      4  220000      525924
# 0  Toyota  White     34564      4   50000      103692

# %%
data_shuffle.reset_index(drop=True)
# Out:
#      Make Colour  Odometer  Doors   Price  total_fuel
# 0   Honda    Red      3456      4   70000       17280
# 1     Bmw  Black     34567      3   40000      138268
# 2     Bmw   Blue     34567      4  560000      172835
# 3  Nissan   Blue     87654      4  220000      525924
# 4  Nissan  Black      8765      4   90000       26295
# 5   Honda  White     65466      4   80000      261864
# 6  Toyota  White     34564      4   50000      103692
# 7     Bmw  White      2344      4  120000       14064
# 8  Toyota   Blue       345      4   70000        1725
# 9     Bmw  Green      9876      5   70000       49380

# %%
data["Odometer"]= data["Odometer"].apply(lambda x:x/1.6)

# %%
data
# Out:
#      Make Colour   Odometer  Doors   Price  total_fuel
# 0  Toyota  White  21602.500      4   50000      103692
# 1   Honda    Red   2160.000      4   70000       17280
# 2     Bmw   Blue  21604.375      4  560000      172835
# 3     Bmw  Black  21604.375      3   40000      138268
# 4     Bmw  Green   6172.500      5   70000       49380
# 5  Nissan   Blue  54783.750      4  220000      525924
# 6  Toyota   Blue    215.625      4   70000        1725
# 7   Honda  White  40916.250      4   80000      261864
# 8     Bmw  White   1465.000      4  120000       14064
# 9  Nissan  Black   5478.125      4   90000       26295
